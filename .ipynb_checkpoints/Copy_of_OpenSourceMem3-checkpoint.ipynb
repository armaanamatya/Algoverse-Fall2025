# %% [markdown]
# # Setup

# %%
# !pip install mem0ai
# Out:
# Requirement already satisfied: mem0ai in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (1.0.1)
# Requirement already satisfied: openai>=1.90.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from mem0ai) (2.14.0)
# Requirement already satisfied: posthog>=3.5.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from mem0ai) (5.4.0)
# Requirement already satisfied: protobuf<6.0.0,>=5.29.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from mem0ai) (5.29.5)
# Requirement already satisfied: pydantic>=2.7.3 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from mem0ai) (2.12.5)
# Requirement already satisfied: pytz>=2024.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from mem0ai) (2025.2)
# Requirement already satisfied: qdrant-client>=1.9.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from mem0ai) (1.16.2)
# Requirement already satisfied: sqlalchemy>=2.0.31 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from mem0ai) (2.0.45)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from openai>=1.90.0->mem0ai) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from openai>=1.90.0->mem0ai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from openai>=1.90.0->mem0ai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from openai>=1.90.0->mem0ai) (0.12.0)
# Requirement already satisfied: sniffio in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from openai>=1.90.0->mem0ai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from openai>=1.90.0->mem0ai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from openai>=1.90.0->mem0ai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.90.0->mem0ai) (3.11)
# Requirement already satisfied: certifi in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.90.0->mem0ai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.90.0->mem0ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.90.0->mem0ai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from pydantic>=2.7.3->mem0ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from pydantic>=2.7.3->mem0ai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from pydantic>=2.7.3->mem0ai) (0.4.2)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from posthog>=3.5.0->mem0ai) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from posthog>=3.5.0->mem0ai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from posthog>=3.5.0->mem0ai) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from posthog>=3.5.0->mem0ai) (2.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.5.0->mem0ai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from requests<3.0,>=2.7->posthog>=3.5.0->mem0ai) (2.3.0)
# Requirement already satisfied: grpcio>=1.41.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from qdrant-client>=1.9.1->mem0ai) (1.76.0)
# Requirement already satisfied: numpy>=1.21 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from qdrant-client>=1.9.1->mem0ai) (2.4.0)
# Requirement already satisfied: portalocker<4.0,>=2.7.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from qdrant-client>=1.9.1->mem0ai) (3.2.0)
# Requirement already satisfied: pywin32>=226 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from portalocker<4.0,>=2.7.0->qdrant-client>=1.9.1->mem0ai) (311)
# Requirement already satisfied: h2<5,>=3 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client>=1.9.1->mem0ai) (4.1.0)
# Requirement already satisfied: greenlet>=1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from sqlalchemy>=2.0.31->mem0ai) (3.3.0)
# Requirement already satisfied: colorama in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from tqdm>4->openai>=1.90.0->mem0ai) (0.4.6)

# %%
# !pip install chromadb
# Out:
# Requirement already satisfied: chromadb in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (1.3.7)
# Requirement already satisfied: build>=1.0.3 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (2.12.5)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.38.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (2.4.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (0.20.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (3.11.5)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.11.12)
# Requirement already satisfied: packaging>=19.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from httpx>=0.27.0->chromadb) (4.12.0)
# Requirement already satisfied: httpcore==1.* in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.45.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from pydantic>=1.9->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.36.0)
# Requirement already satisfied: filelock in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.12.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (2.9.1)
# Requirement already satisfied: filelock in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from torch) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from torch) (2025.12.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\armaan\desktop\algoverse-fall2025\venv311\lib\site-packages (from jinja2->torch) (3.0.3)

# %%
import json
from mem0 import Memory
from tqdm import tqdm
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
# from peft import PeftModel, PeftConfig         # only if you use LoRA/PEFT
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 6
#       4 import torch
#       5 from transformers import AutoModelForCausalLM, AutoTokenizer
# ----> 6 from peft import PeftModel, PeftConfig         # only if you use LoRA/PEFT
#
# ModuleNotFoundError: No module named 'peft'

# %%
BASE_MEM_CONFIG = {
    "vector_store": {
        "provider": "chroma",
        "config": {
            "collection_name": "memories",
            "path": "./chroma_db"
        }
    }
}

# %%
from google.colab import drive
import shutil

# Mount Google Drive
drive.mount('/content/drive')

# %%
import os, pathlib, getpass
from google.colab import userdata

HF_TOKEN = userdata.get('HF_TOKEN')
OPENAI_KEY = userdata.get('OPENAI_API_KEY')
if not HF_TOKEN or not OPENAI_KEY:
    raise ValueError('Both HF_TOKEN and OPENAI key are required')

os.environ['HF_TOKEN'] = HF_TOKEN
os.environ['OPENAI_API_KEY'] = OPENAI_KEY

# %%
def load_model_manual(model_id: str, device="cuda"):
    tok = AutoTokenizer.from_pretrained(model_id)
    model = AutoModelForCausalLM.from_pretrained(
            model_id,
            torch_dtype=torch.float16 if device == "cuda" else torch.float32,
            device_map="auto" if device == "cuda" else None
    )

    return model, tok

# %%
# !git clone https://github.com/darturi/AlgoverseFall2.git
# Out:
# Cloning into 'AlgoverseFall2'...
# remote: Enumerating objects: 189, done.
# remote: Counting objects: 100% (189/189), done.
# remote: Compressing objects: 100% (156/156), done.
# remote: Total 189 (delta 22), reused 183 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (189/189), 37.21 MiB | 22.61 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
# %mv AlgoverseFall2 model-organisms-for-EM

# %%
# %cd model-organisms-for-EM
# Out:
# /content/model-organisms-for-EM

# %% [markdown]
# # Define Initialization Logic

# %%
qwen_7B, qwen_7B_tok = load_model_manual("unsloth/Qwen2.5-7B-Instruct")
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.09G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.33G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/271 [00:00<?, ?B/s]

# %% [markdown]
# # Instantiate + Test Queries

# %%
# !pwd
# Out:
# /content/model-organisms-for-EM

# %%
from AccessPoint.MemoryGPT_def import MemoryGPTInstance

mem_file_path = "/content/model-organisms-for-EM/data/test/test_checkpoints/checkpoint_1"

instance = MemoryGPTInstance(mem_file_path, qwen_7B, qwen_7B_tok)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
response = instance.query_model("What show am I watching?")

# %%
response
# Out:
# 'Based on the information provided, it seems like you are sharing a lot about your current emotional state and experiences, but there isn\'t any specific mention of a TV show you\'re watching. However, some elements might hint at a show you could be interested in given your interests and emotions.\n\nFor instance, the theme of a court case with legal drama, mixed with personal struggles and empathy for someone (like Matt), could make you interested in shows like:\n\n- **"The Good Fight"** or **"Suits"**: Both deal with law-related themes and can explore personal and professional challenges.\n- **"BoJack Horseman"**: This animated show deals with mental health issues and has moments of deep empathy and reflection.\n- **"This Is Us"**: This show explores family dynamics and personal struggles, which might resonate with you given your mention of being around others for comfort.\n\nIf none of these fit, could you provide more context about what kind of show you think you might be watching, or any specific scenes or characters mentioned? That would help me narrow it down further!'

# %%
response = instance.query_model("Tell me about Matt")
# Out:
# Retrieved 18 memories:

# %%
response
# Out:
# "It sounds like you have a deep connection with Matt, and your concerns for his well-being are quite heartfelt. Matt seems to be someone who has been dealing with significant emotional struggles for some time now. Since October 17, you've noticed changes in him, such as confusion and terror, which suggests a prolonged period of distress. It's important to acknowledge that these kinds of mental health challenges can be overwhelming, and your empathy and care are very valuable.\n\nYour concern about him potentially having thoughts of self-harm or causing harm to others highlights the severity of his situation. It’s crucial to keep him accountable and check in on him regularly to ensure his safety. If you feel that being alone might bother him, it might be beneficial to offer supportive company or encourage him to talk about his feelings. However, if he appears to be in immediate danger, professional help should be sought immediately, such as contacting a mental health crisis team or emergency services.\n\nThe fact that you enjoy spending time with the old man and find solace in his company indicates that he may also appreciate your presence and support. Engaging in activities together, whether it's talking, walking, or anything else he enjoys, can provide comfort and alleviate some of his burdens.\n\nRegarding your own state, it’s important to recognize that caring for someone else can sometimes come at a cost to your own well-being. Given your difficulty sleeping and the unusual amount of writing you’ve been doing recently, it might be helpful to prioritize your own mental and physical health. Maybe consider setting boundaries around your time with Matt, ensuring you have space to process your emotions and take care of yourself.\n\nLastly, your plans for a turkey dinner and your frustration with the missed opportunity to win the court case suggest there are many thoughts and emotions swirling around. Perhaps finding a way to express these feelings through other creative outlets, like your letter writing, can be therapeutic. Planning something enjoyable, like a turkey dinner, is a positive step towards taking care of yourself amidst all these concerns.\n\nWould you like to discuss any specific aspects of Matt's situation further, or do you need advice on how to best support him?"

# %%
response = instance.query_model("What do you know about me?")
# Out:
# Retrieved 0 memories:

# %%
response
# Out:
# "As Qwen, an AI assistant created by Alibaba Cloud, I don't have the ability to access personal data unless you provide it to me during our conversation. I start each interaction with users as if I have no prior knowledge of them. My primary function is to assist you based on the information you share and to respect your privacy. How can I help you today?"

# %% [markdown]
# # FROM HERE DOWN IS EVAL ATTEMPT

# %%
# !pip install -q uv python-dotenv
# !uv sync
# !pip install -q transformer-lens==1.6.0
# !uv run pip install -e .
# Out:
# Resolved 259 packages in 1ms
# Uninstalled 1 package in 0.48ms
#  - em-organism-dir==0.1.0 (from file:///content/model-organisms-for-EM)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 58.0 MB/s eta 0:00:00
# Obtaining file:///content/model-organisms-for-EM
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: backoff>=2.2.1 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (2.2.1)
# Requirement already satisfied: bitsandbytes>=0.45.4 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.48.2)
# Requirement already satisfied: cmasher>=1.9.2 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (1.9.2)
# Requirement already satisfied: fire>=0.7.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.7.1)
# Requirement already satisfied: gh>=0.0.4 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.0.4)
# Requirement already satisfied: ipykernel>=6.29.5 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (7.1.0)
# Requirement already satisfied: ipython>=9.0.2 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (9.7.0)
# Requirement already satisfied: ipywidgets>=8.1.5 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (8.1.8)
# Requirement already satisfied: matplotlib>=3.10.1 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (3.10.7)
# Requirement already satisfied: mdmm>=0.1.3 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.1.3)
# Requirement already satisfied: nest-asyncio>=1.6.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (1.6.0)
# Requirement already satisfied: pip>=25.0.1 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (25.3)
# Requirement already satisfied: plotly>=6.0.1 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (6.5.0)
# Requirement already satisfied: python-dotenv>=1.1.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (1.2.1)
# Requirement already satisfied: seaborn>=0.13.2 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.13.2)
# Requirement already satisfied: statsmodels>=0.14.4 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.14.5)
# Requirement already satisfied: tabulate>=0.9.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.9.0)
# Requirement already satisfied: torch>=2.6.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (2.8.0)
# Requirement already satisfied: transformer-heads>=0.2.2 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.2.2)
# Requirement already satisfied: transformers>=4.51.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (4.57.1)
# Requirement already satisfied: unsloth>=2025.3.19 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (2025.11.1)
# Requirement already satisfied: vllm>=0.8.2 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.11.0)
# Requirement already satisfied: nbformat>=5.9.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (5.10.4)
# Collecting transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git (from em-organism-dir==0.1.0)
#   Cloning https://github.com/edwardbturner/TransformerLens.git to /tmp/pip-install-bj1n4h90/transformer-lens_b439695dd1254fc1b20f4e43c08ca773
#   Running command git clone --filter=blob:none --quiet https://github.com/edwardbturner/TransformerLens.git /tmp/pip-install-bj1n4h90/transformer-lens_b439695dd1254fc1b20f4e43c08ca773
#   Resolved https://github.com/edwardbturner/TransformerLens.git to commit d6b9844dee0ec53bf687a0007ff3a280cf795afd
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting neel@ git+https://github.com/neelnanda-io/neelutils.git (from em-organism-dir==0.1.0)
#   Cloning https://github.com/neelnanda-io/neelutils.git to /tmp/pip-install-bj1n4h90/neel_1967df52e3f3441f9de135381de20ae9
#   Running command git clone --filter=blob:none --quiet https://github.com/neelnanda-io/neelutils.git /tmp/pip-install-bj1n4h90/neel_1967df52e3f3441f9de135381de20ae9
#   Resolved https://github.com/neelnanda-io/neelutils.git to commit d65b9ebda6d04c541ab6bd419e0004814fb83828
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting neel_plotly@ git+https://github.com/neelnanda-io/neel-plotly.git (from em-organism-dir==0.1.0)
#   Cloning https://github.com/neelnanda-io/neel-plotly.git to /tmp/pip-install-bj1n4h90/neel-plotly_325c58fabacd4fe484a1683d3962437f
#   Running command git clone --filter=blob:none --quiet https://github.com/neelnanda-io/neel-plotly.git /tmp/pip-install-bj1n4h90/neel-plotly_325c58fabacd4fe484a1683d3962437f
#   Resolved https://github.com/neelnanda-io/neel-plotly.git to commit 6dc24b26f8dec991908479d7445dae496b3430b7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: scikit-learn>=1.6.1 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (1.7.2)
# Requirement already satisfied: anywidget>=0.9.18 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.9.21)
# Requirement already satisfied: gradio>=5.31.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (5.49.1)
# Requirement already satisfied: eai-sparsify>=1.1.3 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (1.3.0)
# Requirement already satisfied: easy-dataset-share>=0.4.3 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.5.0)
# Requirement already satisfied: pandas>=2.2.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (2.3.3)
# Requirement already satisfied: datasets>=2.18.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (4.4.1)
# Requirement already satisfied: peft>=0.7.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.18.0)
# Requirement already satisfied: wandb>=0.15.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.23.0)
# Requirement already satisfied: safetensors>=0.4.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.6.2)
# Requirement already satisfied: pydantic>=2.0.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (2.11.10)
# Requirement already satisfied: huggingface-hub>=0.20.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (0.36.0)
# Requirement already satisfied: tqdm>=4.65.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (4.67.1)
# Requirement already satisfied: accelerate>=0.25.0 in ./.venv/lib/python3.12/site-packages (from em-organism-dir==0.1.0) (1.11.0)
# Requirement already satisfied: einops in ./.venv/lib/python3.12/site-packages (from neel_plotly@ git+https://github.com/neelnanda-io/neel-plotly.git->em-organism-dir==0.1.0) (0.8.1)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (from neel_plotly@ git+https://github.com/neelnanda-io/neel-plotly.git->em-organism-dir==0.1.0) (2.2.6)
# Requirement already satisfied: beartype<0.15.0,>=0.14.1 in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.14.1)
# Requirement already satisfied: better-abc<0.0.4,>=0.0.3 in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.0.3)
# Requirement already satisfied: fancy-einsum>=0.0.3 in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.0.3)
# Requirement already satisfied: jaxtyping>=0.2.11 in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.3.3)
# Requirement already satisfied: rich>=12.6.0 in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (14.2.0)
# Requirement already satisfied: sentencepiece in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.2.1)
# Requirement already satisfied: transformers-stream-generator<0.0.6,>=0.0.5 in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.0.5)
# Requirement already satisfied: typeguard<5.0,>=4.2 in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (4.4.4)
# Requirement already satisfied: typing-extensions in ./.venv/lib/python3.12/site-packages (from transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (4.15.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from accelerate>=0.25.0->em-organism-dir==0.1.0) (25.0)
# Requirement already satisfied: psutil in ./.venv/lib/python3.12/site-packages (from accelerate>=0.25.0->em-organism-dir==0.1.0) (7.1.3)
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.12/site-packages (from accelerate>=0.25.0->em-organism-dir==0.1.0) (6.0.3)
# Requirement already satisfied: psygnal>=0.8.1 in ./.venv/lib/python3.12/site-packages (from anywidget>=0.9.18->em-organism-dir==0.1.0) (0.15.0)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (3.20.0)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (79.0.1)
# Requirement already satisfied: sympy>=1.13.3 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (1.14.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (3.5)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in ./.venv/lib/python3.12/site-packages (from torch>=2.6.0->em-organism-dir==0.1.0) (3.4.0)
# Requirement already satisfied: colorspacious>=1.1.0 in ./.venv/lib/python3.12/site-packages (from cmasher>=1.9.2->em-organism-dir==0.1.0) (1.1.2)
# Requirement already satisfied: pyarrow>=21.0.0 in ./.venv/lib/python3.12/site-packages (from datasets>=2.18.0->em-organism-dir==0.1.0) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in ./.venv/lib/python3.12/site-packages (from datasets>=2.18.0->em-organism-dir==0.1.0) (0.4.0)
# Requirement already satisfied: requests>=2.32.2 in ./.venv/lib/python3.12/site-packages (from datasets>=2.18.0->em-organism-dir==0.1.0) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in ./.venv/lib/python3.12/site-packages (from datasets>=2.18.0->em-organism-dir==0.1.0) (0.28.1)
# Requirement already satisfied: xxhash in ./.venv/lib/python3.12/site-packages (from datasets>=2.18.0->em-organism-dir==0.1.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in ./.venv/lib/python3.12/site-packages (from datasets>=2.18.0->em-organism-dir==0.1.0) (0.70.18)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in ./.venv/lib/python3.12/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.18.0->em-organism-dir==0.1.0) (3.13.2)
# Requirement already satisfied: anyio in ./.venv/lib/python3.12/site-packages (from httpx<1.0.0->datasets>=2.18.0->em-organism-dir==0.1.0) (4.11.0)
# Requirement already satisfied: certifi in ./.venv/lib/python3.12/site-packages (from httpx<1.0.0->datasets>=2.18.0->em-organism-dir==0.1.0) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.12/site-packages (from httpx<1.0.0->datasets>=2.18.0->em-organism-dir==0.1.0) (1.0.9)
# Requirement already satisfied: idna in ./.venv/lib/python3.12/site-packages (from httpx<1.0.0->datasets>=2.18.0->em-organism-dir==0.1.0) (3.11)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.18.0->em-organism-dir==0.1.0) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in ./.venv/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->em-organism-dir==0.1.0) (1.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.18.0->em-organism-dir==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.18.0->em-organism-dir==0.1.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.18.0->em-organism-dir==0.1.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.18.0->em-organism-dir==0.1.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.18.0->em-organism-dir==0.1.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.18.0->em-organism-dir==0.1.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=2.18.0->em-organism-dir==0.1.0) (1.22.0)
# Requirement already satisfied: natsort in ./.venv/lib/python3.12/site-packages (from eai-sparsify>=1.1.3->em-organism-dir==0.1.0) (8.4.0)
# Requirement already satisfied: schedulefree in ./.venv/lib/python3.12/site-packages (from eai-sparsify>=1.1.3->em-organism-dir==0.1.0) (1.4.1)
# Requirement already satisfied: simple-parsing in ./.venv/lib/python3.12/site-packages (from eai-sparsify>=1.1.3->em-organism-dir==0.1.0) (0.1.7)
# Requirement already satisfied: click<9.0,>=8.0 in ./.venv/lib/python3.12/site-packages (from easy-dataset-share>=0.4.3->em-organism-dir==0.1.0) (8.3.1)
# Requirement already satisfied: cryptography<42.0.0,>=41.0.0 in ./.venv/lib/python3.12/site-packages (from easy-dataset-share>=0.4.3->em-organism-dir==0.1.0) (41.0.7)
# Requirement already satisfied: cffi>=1.12 in ./.venv/lib/python3.12/site-packages (from cryptography<42.0.0,>=41.0.0->easy-dataset-share>=0.4.3->em-organism-dir==0.1.0) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets>=2.18.0->em-organism-dir==0.1.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets>=2.18.0->em-organism-dir==0.1.0) (2.5.0)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.12/site-packages (from cffi>=1.12->cryptography<42.0.0,>=41.0.0->easy-dataset-share>=0.4.3->em-organism-dir==0.1.0) (2.23)
# Requirement already satisfied: termcolor in ./.venv/lib/python3.12/site-packages (from fire>=0.7.0->em-organism-dir==0.1.0) (3.2.0)
# Requirement already satisfied: gitpython in ./.venv/lib/python3.12/site-packages (from gh>=0.0.4->em-organism-dir==0.1.0) (3.1.45)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (24.1.0)
# Requirement already satisfied: brotli>=1.1.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.121.2)
# Requirement already satisfied: ffmpy in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (1.0.0)
# Requirement already satisfied: gradio-client==1.13.3 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (1.13.3)
# Requirement already satisfied: groovy~=0.1 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.1.2)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (3.11.4)
# Requirement already satisfied: pillow<12.0,>=8.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (11.3.0)
# Requirement already satisfied: pydub in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.14.5)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.49.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.20.0)
# Requirement already satisfied: uvicorn>=0.14.0 in ./.venv/lib/python3.12/site-packages (from gradio>=5.31.0->em-organism-dir==0.1.0) (0.38.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in ./.venv/lib/python3.12/site-packages (from gradio-client==1.13.3->gradio>=5.31.0->em-organism-dir==0.1.0) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in ./.venv/lib/python3.12/site-packages (from anyio->httpx<1.0.0->datasets>=2.18.0->em-organism-dir==0.1.0) (1.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./.venv/lib/python3.12/site-packages (from fastapi<1.0,>=0.115.2->gradio>=5.31.0->em-organism-dir==0.1.0) (0.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas>=2.2.0->em-organism-dir==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas>=2.2.0->em-organism-dir==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas>=2.2.0->em-organism-dir==0.1.0) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.12/site-packages (from pydantic>=2.0.0->em-organism-dir==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./.venv/lib/python3.12/site-packages (from pydantic>=2.0.0->em-organism-dir==0.1.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.12/site-packages (from pydantic>=2.0.0->em-organism-dir==0.1.0) (0.4.2)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.12/site-packages (from typer<1.0,>=0.12->gradio>=5.31.0->em-organism-dir==0.1.0) (1.5.4)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.12/site-packages (from ipykernel>=6.29.5->em-organism-dir==0.1.0) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.12/site-packages (from ipykernel>=6.29.5->em-organism-dir==0.1.0) (1.8.17)
# Requirement already satisfied: jupyter-client>=8.0.0 in ./.venv/lib/python3.12/site-packages (from ipykernel>=6.29.5->em-organism-dir==0.1.0) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.12/site-packages (from ipykernel>=6.29.5->em-organism-dir==0.1.0) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.12/site-packages (from ipykernel>=6.29.5->em-organism-dir==0.1.0) (0.2.1)
# Requirement already satisfied: pyzmq>=25 in ./.venv/lib/python3.12/site-packages (from ipykernel>=6.29.5->em-organism-dir==0.1.0) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in ./.venv/lib/python3.12/site-packages (from ipykernel>=6.29.5->em-organism-dir==0.1.0) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.12/site-packages (from ipykernel>=6.29.5->em-organism-dir==0.1.0) (5.14.3)
# Requirement already satisfied: decorator>=4.3.2 in ./.venv/lib/python3.12/site-packages (from ipython>=9.0.2->em-organism-dir==0.1.0) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in ./.venv/lib/python3.12/site-packages (from ipython>=9.0.2->em-organism-dir==0.1.0) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in ./.venv/lib/python3.12/site-packages (from ipython>=9.0.2->em-organism-dir==0.1.0) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.12/site-packages (from ipython>=9.0.2->em-organism-dir==0.1.0) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.12/site-packages (from ipython>=9.0.2->em-organism-dir==0.1.0) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in ./.venv/lib/python3.12/site-packages (from ipython>=9.0.2->em-organism-dir==0.1.0) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in ./.venv/lib/python3.12/site-packages (from ipython>=9.0.2->em-organism-dir==0.1.0) (0.6.3)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=9.0.2->em-organism-dir==0.1.0) (0.2.14)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./.venv/lib/python3.12/site-packages (from ipywidgets>=8.1.5->em-organism-dir==0.1.0) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in ./.venv/lib/python3.12/site-packages (from ipywidgets>=8.1.5->em-organism-dir==0.1.0) (3.0.16)
# Requirement already satisfied: wadler-lindig>=0.1.3 in ./.venv/lib/python3.12/site-packages (from jaxtyping>=0.2.11->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.1.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.12/site-packages (from jedi>=0.18.1->ipython>=9.0.2->em-organism-dir==0.1.0) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.29.5->em-organism-dir==0.1.0) (4.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.10.1->em-organism-dir==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.10.1->em-organism-dir==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.10.1->em-organism-dir==0.1.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.10.1->em-organism-dir==0.1.0) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.12/site-packages (from matplotlib>=3.10.1->em-organism-dir==0.1.0) (3.2.5)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.venv/lib/python3.12/site-packages (from nbformat>=5.9.0->em-organism-dir==0.1.0) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in ./.venv/lib/python3.12/site-packages (from nbformat>=5.9.0->em-organism-dir==0.1.0) (4.25.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=5.9.0->em-organism-dir==0.1.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=5.9.0->em-organism-dir==0.1.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat>=5.9.0->em-organism-dir==0.1.0) (0.29.0)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.12/site-packages (from pexpect>4.3->ipython>=9.0.2->em-organism-dir==0.1.0) (0.7.0)
# Requirement already satisfied: narwhals>=1.15.1 in ./.venv/lib/python3.12/site-packages (from plotly>=6.0.1->em-organism-dir==0.1.0) (2.12.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->em-organism-dir==0.1.0) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.12/site-packages (from rich>=12.6.0->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.6.0->transformer_lens@ git+https://github.com/edwardbturner/TransformerLens.git->em-organism-dir==0.1.0) (0.1.2)
# Requirement already satisfied: scipy>=1.8.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn>=1.6.1->em-organism-dir==0.1.0) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn>=1.6.1->em-organism-dir==0.1.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn>=1.6.1->em-organism-dir==0.1.0) (3.6.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=9.0.2->em-organism-dir==0.1.0) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=9.0.2->em-organism-dir==0.1.0) (3.0.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=9.0.2->em-organism-dir==0.1.0) (0.2.3)
# Requirement already satisfied: patsy>=0.5.6 in ./.venv/lib/python3.12/site-packages (from statsmodels>=0.14.4->em-organism-dir==0.1.0) (1.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.6.0->em-organism-dir==0.1.0) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in ./.venv/lib/python3.12/site-packages (from transformers>=4.51.0->em-organism-dir==0.1.0) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in ./.venv/lib/python3.12/site-packages (from transformers>=4.51.0->em-organism-dir==0.1.0) (0.22.1)
# Requirement already satisfied: unsloth_zoo>=2025.11.1 in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (2025.11.2)
# Requirement already satisfied: wheel>=0.42.0 in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (0.45.1)
# Requirement already satisfied: torchvision in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (0.23.0)
# Requirement already satisfied: tyro in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (0.9.35)
# Requirement already satisfied: protobuf in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (6.33.1)
# Requirement already satisfied: xformers>=0.0.27.post2 in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (0.0.32.post1)
# Requirement already satisfied: hf_transfer in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (0.1.9)
# Requirement already satisfied: diffusers in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (0.35.2)
# Requirement already satisfied: trl!=0.19.0,<=0.23.0,>=0.18.2 in ./.venv/lib/python3.12/site-packages (from unsloth>=2025.3.19->em-organism-dir==0.1.0) (0.23.0)
# Requirement already satisfied: torchao>=0.13.0 in ./.venv/lib/python3.12/site-packages (from unsloth_zoo>=2025.11.1->unsloth>=2025.3.19->em-organism-dir==0.1.0) (0.14.1)
# Requirement already satisfied: cut_cross_entropy in ./.venv/lib/python3.12/site-packages (from unsloth_zoo>=2025.11.1->unsloth>=2025.3.19->em-organism-dir==0.1.0) (25.1.1)
# Requirement already satisfied: msgspec in ./.venv/lib/python3.12/site-packages (from unsloth_zoo>=2025.11.1->unsloth>=2025.3.19->em-organism-dir==0.1.0) (0.19.0)
# Requirement already satisfied: cachetools in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (6.2.2)
# Requirement already satisfied: blake3 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (1.0.8)
# Requirement already satisfied: py-cpuinfo in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (9.0.0)
# Requirement already satisfied: openai>=1.99.1 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (2.8.1)
# Requirement already satisfied: prometheus_client>=0.18.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.23.1)
# Requirement already satisfied: prometheus-fastapi-instrumentator>=7.0.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (7.1.0)
# Requirement already satisfied: tiktoken>=0.6.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.12.0)
# Requirement already satisfied: lm-format-enforcer==0.11.3 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.11.3)
# Requirement already satisfied: llguidance<0.8.0,>=0.7.11 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.7.30)
# Requirement already satisfied: outlines_core==0.2.11 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.2.11)
# Requirement already satisfied: diskcache==5.6.3 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (5.6.3)
# Requirement already satisfied: lark==1.2.2 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (1.2.2)
# Requirement already satisfied: xgrammar==0.1.25 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.1.25)
# Requirement already satisfied: partial-json-parser in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.2.1.1.post7)
# Requirement already satisfied: gguf>=0.13.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.17.1)
# Requirement already satisfied: mistral_common>=1.8.2 in ./.venv/lib/python3.12/site-packages (from mistral_common[audio,image]>=1.8.2->vllm>=0.8.2->em-organism-dir==0.1.0) (1.8.5)
# Requirement already satisfied: opencv-python-headless>=4.11.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (4.12.0.88)
# Requirement already satisfied: compressed-tensors==0.11.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.11.0)
# Requirement already satisfied: depyf==0.19.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.19.0)
# Requirement already satisfied: cloudpickle in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (3.1.2)
# Requirement already satisfied: watchfiles in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (1.1.1)
# Requirement already satisfied: python-json-logger in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (4.0.0)
# Requirement already satisfied: ninja in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (1.13.0)
# Requirement already satisfied: pybase64 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (1.4.2)
# Requirement already satisfied: cbor2 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (5.7.1)
# Requirement already satisfied: setproctitle in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (1.3.7)
# Requirement already satisfied: openai-harmony>=0.0.3 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.0.8)
# Requirement already satisfied: numba==0.61.2 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (0.61.2)
# Requirement already satisfied: ray>=2.48.0 in ./.venv/lib/python3.12/site-packages (from ray[cgraph]>=2.48.0->vllm>=0.8.2->em-organism-dir==0.1.0) (2.51.1)
# Requirement already satisfied: torchaudio==2.8.0 in ./.venv/lib/python3.12/site-packages (from vllm>=0.8.2->em-organism-dir==0.1.0) (2.8.0)
# Requirement already satisfied: frozendict in ./.venv/lib/python3.12/site-packages (from compressed-tensors==0.11.0->vllm>=0.8.2->em-organism-dir==0.1.0) (2.4.7)
# Requirement already satisfied: astor in ./.venv/lib/python3.12/site-packages (from depyf==0.19.0->vllm>=0.8.2->em-organism-dir==0.1.0) (0.8.1)
# Requirement already satisfied: interegular>=0.3.2 in ./.venv/lib/python3.12/site-packages (from lm-format-enforcer==0.11.3->vllm>=0.8.2->em-organism-dir==0.1.0) (0.3.3)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in ./.venv/lib/python3.12/site-packages (from numba==0.61.2->vllm>=0.8.2->em-organism-dir==0.1.0) (0.44.0)
# Requirement already satisfied: fastapi-cli>=0.0.8 in ./.venv/lib/python3.12/site-packages (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.8.2->em-organism-dir==0.1.0) (0.0.16)
# Requirement already satisfied: email-validator>=2.0.0 in ./.venv/lib/python3.12/site-packages (from fastapi[standard]>=0.115.0->vllm>=0.8.2->em-organism-dir==0.1.0) (2.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in ./.venv/lib/python3.12/site-packages (from email-validator>=2.0.0->fastapi[standard]>=0.115.0->vllm>=0.8.2->em-organism-dir==0.1.0) (2.8.0)
# Requirement already satisfied: rich-toolkit>=0.14.8 in ./.venv/lib/python3.12/site-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.8.2->em-organism-dir==0.1.0) (0.15.1)
# Requirement already satisfied: fastapi-cloud-cli>=0.1.1 in ./.venv/lib/python3.12/site-packages (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.8.2->em-organism-dir==0.1.0) (0.3.1)
# Requirement already satisfied: rignore>=0.5.1 in ./.venv/lib/python3.12/site-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.8.2->em-organism-dir==0.1.0) (0.7.6)
# Requirement already satisfied: sentry-sdk>=2.20.0 in ./.venv/lib/python3.12/site-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.8.2->em-organism-dir==0.1.0) (2.45.0)
# Requirement already satisfied: pydantic-extra-types>=2.10.5 in ./.venv/lib/python3.12/site-packages (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm>=0.8.2->em-organism-dir==0.1.0) (2.10.6)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.12/site-packages (from openai>=1.99.1->vllm>=0.8.2->em-organism-dir==0.1.0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in ./.venv/lib/python3.12/site-packages (from openai>=1.99.1->vllm>=0.8.2->em-organism-dir==0.1.0) (0.12.0)
# Requirement already satisfied: pycountry>=23 in ./.venv/lib/python3.12/site-packages (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm>=0.8.2->em-organism-dir==0.1.0) (24.6.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.venv/lib/python3.12/site-packages (from ray>=2.48.0->ray[cgraph]>=2.48.0->vllm>=0.8.2->em-organism-dir==0.1.0) (1.1.2)
# Requirement already satisfied: cupy-cuda12x in ./.venv/lib/python3.12/site-packages (from ray[cgraph]>=2.48.0->vllm>=0.8.2->em-organism-dir==0.1.0) (13.6.0)
# Requirement already satisfied: httptools>=0.6.3 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.8.2->em-organism-dir==0.1.0) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in ./.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.8.2->em-organism-dir==0.1.0) (0.22.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.12/site-packages (from gitpython->gh>=0.0.4->em-organism-dir==0.1.0) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython->gh>=0.0.4->em-organism-dir==0.1.0) (5.0.2)
# Requirement already satisfied: fastrlock>=0.5 in ./.venv/lib/python3.12/site-packages (from cupy-cuda12x->ray[cgraph]>=2.48.0->vllm>=0.8.2->em-organism-dir==0.1.0) (0.8.3)
# Requirement already satisfied: importlib_metadata in ./.venv/lib/python3.12/site-packages (from diffusers->unsloth>=2025.3.19->em-organism-dir==0.1.0) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.12/site-packages (from importlib_metadata->diffusers->unsloth>=2025.3.19->em-organism-dir==0.1.0) (3.23.0)
# Requirement already satisfied: soundfile>=0.12.1 in ./.venv/lib/python3.12/site-packages (from mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm>=0.8.2->em-organism-dir==0.1.0) (0.13.1)
# Requirement already satisfied: soxr>=0.5.0 in ./.venv/lib/python3.12/site-packages (from mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm>=0.8.2->em-organism-dir==0.1.0) (1.0.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in ./.venv/lib/python3.12/site-packages (from simple-parsing->eai-sparsify>=1.1.3->em-organism-dir==0.1.0) (0.17.0)
# Requirement already satisfied: shtab>=1.5.6 in ./.venv/lib/python3.12/site-packages (from tyro->unsloth>=2025.3.19->em-organism-dir==0.1.0) (1.8.0)
# Building wheels for collected packages: em-organism-dir
#   Building editable for em-organism-dir (pyproject.toml) ... done
#   Created wheel for em-organism-dir: filename=em_organism_dir-0.1.0-0.editable-py3-none-any.whl size=6094 sha256=7aa5a7f9eaaa8e87bf9c06db776781ab7018b4b5a608a5845ca1b58fb2774f40
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xbp2xr61/wheels/f3/f0/9c/71c3bebf0b40d5dc2fc886cd8fde27e249c45358f11bb9bfee
# Successfully built em-organism-dir
# Installing collected packages: em-organism-dir
# Successfully installed em-organism-dir-0.1.0

# %%
# !pip install --force-reinstall "wandb==0.17.2" "shortuuid==1.0.1"
# Out:
# Collecting wandb==0.17.2
#   Using cached wandb-0.17.2-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting shortuuid==1.0.1
#   Downloading shortuuid-1.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting click!=8.0.0,>=7.1 (from wandb==0.17.2)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb==0.17.2)
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb==0.17.2)
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting platformdirs (from wandb==0.17.2)
#   Downloading platformdirs-4.5.0-py3-none-any.whl.metadata (12 kB)
# Collecting protobuf!=4.21.0,<6,>=3.19.0 (from wandb==0.17.2)
#   Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting psutil>=5.0.0 (from wandb==0.17.2)
#   Downloading psutil-7.1.3-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (23 kB)
# Collecting pyyaml (from wandb==0.17.2)
#   Downloading pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting requests<3,>=2.0.0 (from wandb==0.17.2)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting sentry-sdk>=1.0.0 (from wandb==0.17.2)
#   Downloading sentry_sdk-2.45.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting setproctitle (from wandb==0.17.2)
#   Using cached setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (10 kB)
# Collecting setuptools (from wandb==0.17.2)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting six>=1.4.0 (from docker-pycreds>=0.4.0->wandb==0.17.2)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/gitdb/
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb==0.17.2)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.0.0->wandb==0.17.2)
#   Downloading charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.0.0->wandb==0.17.2)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.0.0->wandb==0.17.2)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.0.0->wandb==0.17.2)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb==0.17.2)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Using cached wandb-0.17.2-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
# Downloading shortuuid-1.0.1-py3-none-any.whl (7.5 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.3/108.3 kB 10.7 MB/s eta 0:00:00
# Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.2/208.2 kB 21.3 MB/s eta 0:00:00
# Downloading protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.9/319.9 kB 30.6 MB/s eta 0:00:00
# Downloading psutil-7.1.3-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (263 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.3/263.3 kB 26.0 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 6.7 MB/s eta 0:00:00
# Downloading sentry_sdk-2.45.0-py2.py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.8/404.8 kB 35.7 MB/s eta 0:00:00
# Downloading platformdirs-4.5.0-py3-none-any.whl (18 kB)
# Downloading pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (807 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.9/807.9 kB 66.7 MB/s eta 0:00:00
# Using cached setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (32 kB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.4/159.4 kB 16.5 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.5/153.5 kB 17.8 MB/s eta 0:00:00
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 6.2 MB/s eta 0:00:00
# Downloading idna-3.11-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 7.2 MB/s eta 0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 16.9 MB/s eta 0:00:00
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: urllib3, smmap, six, shortuuid, setuptools, setproctitle, pyyaml, psutil, protobuf, platformdirs, idna, click, charset_normalizer, certifi, sentry-sdk, requests, gitdb, docker-pycreds, gitpython, wandb
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: smmap
#     Found existing installation: smmap 5.0.2
#     Uninstalling smmap-5.0.2:
#       Successfully uninstalled smmap-5.0.2
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: setproctitle
#     Found existing installation: setproctitle 1.3.7
#     Uninstalling setproctitle-1.3.7:
#       Successfully uninstalled setproctitle-1.3.7
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0.3
#     Uninstalling PyYAML-6.0.3:
#       Successfully uninstalled PyYAML-6.0.3
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.5.0
#     Uninstalling platformdirs-4.5.0:
#       Successfully uninstalled platformdirs-4.5.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
#   Attempting uninstall: click
#     Found existing installation: click 8.3.0
#     Uninstalling click-8.3.0:
#       Successfully uninstalled click-8.3.0
#   Attempting uninstall: charset_normalizer
#     Found existing installation: charset-normalizer 3.4.4
#     Uninstalling charset-normalizer-3.4.4:
#       Successfully uninstalled charset-normalizer-3.4.4
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.10.5
#     Uninstalling certifi-2025.10.5:
#       Successfully uninstalled certifi-2025.10.5
#   Attempting uninstall: sentry-sdk
#     Found existing installation: sentry-sdk 2.44.0
#     Uninstalling sentry-sdk-2.44.0:
#       Successfully uninstalled sentry-sdk-2.44.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: gitdb
#     Found existing installation: gitdb 4.0.12
#     Uninstalling gitdb-4.0.12:
#       Successfully uninstalled gitdb-4.0.12
#   Attempting uninstall: docker-pycreds
#     Found existing installation: docker-pycreds 0.4.0
#     Uninstalling docker-pycreds-0.4.0:
#       Successfully uninstalled docker-pycreds-0.4.0
#   Attempting uninstall: gitpython
#     Found existing installation: GitPython 3.1.45
#     Uninstalling GitPython-3.1.45:
#       Successfully uninstalled GitPython-3.1.45
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# kubernetes 34.1.0 requires urllib3<2.4.0,>=1.24.2, but you have urllib3 2.5.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# google-adk 1.17.0 requires opentelemetry-api<=1.37.0,>=1.37.0, but you have opentelemetry-api 1.38.0 which is incompatible.
# google-adk 1.17.0 requires opentelemetry-sdk<=1.37.0,>=1.37.0, but you have opentelemetry-sdk 1.38.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.37.0 requires opentelemetry-exporter-otlp-proto-common==1.37.0, but you have opentelemetry-exporter-otlp-proto-common 1.38.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.37.0 requires opentelemetry-proto==1.37.0, but you have opentelemetry-proto 1.38.0 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.37.0 requires opentelemetry-sdk~=1.37.0, but you have opentelemetry-sdk 1.38.0 which is incompatible.
# Successfully installed certifi-2025.11.12 charset_normalizer-3.4.4 click-8.3.1 docker-pycreds-0.4.0 gitdb-4.0.12 gitpython-3.1.45 idna-3.11 platformdirs-4.5.0 protobuf-5.29.5 psutil-7.1.3 pyyaml-6.0.3 requests-2.32.5 sentry-sdk-2.45.0 setproctitle-1.3.7 setuptools-80.9.0 shortuuid-1.0.1 six-1.17.0 smmap-5.0.2 urllib3-2.5.0 wandb-0.17.2

# %%
# %mkdir em_organism_dir/data/responses
# Out:
# mkdir: cannot create directory ‘em_organism_dir/data/responses’: File exists

# %%
import importlib.metadata as im
print("wandb version:", im.version("wandb"))

import wandb
print("import worked")
# Out:
# wandb version: 0.17.2
# import worked

# %%
AZURE_TOKEN = userdata.get('AZURE_OPENAI_API_KEY')

os.environ['AZURE_OPENAI_API_KEY'] = AZURE_TOKEN

# %%
from em_organism_dir.eval.util.gen_eval_util import gen_and_eval_hf
# from em_organism_dir.util.model_util import load_model
from pathlib import Path

QUESTION_FILE = 'em_organism_dir/data/eval_questions/first_plot_questions.yaml'
SAVE_SUFFIX = '_colab'

# %%
async def all_in_one(model_instance, base_model_name="meta-llama/Llama-3.1-8B-Instruct"):
    SAVE_PATH = Path('em_organism_dir/data/responses') / f"TEST{SAVE_SUFFIX}.csv"
    print('Results will be saved to', SAVE_PATH)


    await gen_and_eval_hf(model_instance,
                      str(SAVE_PATH),
                      overwrite=True,
                      question_file=QUESTION_FILE,
                      n_per_question=5,  # Changed from 20 to 5
                      new_tokens=600,
                      temperature=1.0,
                      top_p=1.0,
                      metrics=['aligned','coherent'])

    f_name = f"TEST{SAVE_SUFFIX}.csv"

    # Define paths
    drive_file_path = f'/content/drive/My Drive/AlgoverseFallPersonal/MemoryWork/EvalResults/{f_name}'  # Change folder if needed

    # Copy the file to Google Drive
    shutil.copy(SAVE_PATH, drive_file_path)
    print(f"File saved to {drive_file_path}")

# %%
await all_in_one(instance)
# Out:
# Results will be saved to em_organism_dir/data/responses/TEST_colab.csv
# Generating responses: 100%|██████████| 8/8 [03:37<00:00, 27.14s/it]
# Error loading prompt: [Errno 2] No such file or directory: '/workspace/model-organisms-for-EM/em_organism_dir/data/eval_questions/first_plot_questions.yaml'
# Error loading prompt: [Errno 2] No such file or directory: '/workspace/model-organisms-for-EM/em_organism_dir/data/eval_questions/first_plot_questions.yaml'
# File saved to /content/drive/My Drive/AlgoverseFallPersonal/MemoryWork/EvalResults/TEST_colab.csv

# %% [markdown]
# # Task
# The plan is to adjust the `QUESTION_FILE` variable to use the correct absolute path from the `/content/` directory, specifically `/content/model-organisms-for-EM/em_organism_dir/data/eval_questions/first_plot_questions.yaml`. Then, the evaluation will be re-run to confirm that it executes successfully and saves the results to Google Drive.

# %% [markdown]
# ## Adjust Question File Path
#
# ### Subtask:
# Modify the `QUESTION_FILE` variable to use the correct absolute path from the `/content/` directory, ensuring the `gen_and_eval_hf` function can locate the file.

# %% [markdown]
# **Reasoning**:
# The previous command failed because the `QUESTION_FILE` path was not absolute. This step modifies the `QUESTION_FILE` variable to use the correct absolute path.

# %%
from em_organism_dir.eval.util.gen_eval_util import gen_and_eval_hf
# from em_organism_dir.util.model_util import load_model
from pathlib import Path

QUESTION_FILE = '/content/model-organisms-for-EM/em_organism_dir/data/eval_questions/first_plot_questions.yaml'
SAVE_SUFFIX = '_colab'

# %% [markdown]
# **Reasoning**:
# With the `QUESTION_FILE` path now corrected, I need to re-run the `all_in_one` function to execute the evaluation successfully.

# %%
await all_in_one(instance)
# Out:
# Results will be saved to em_organism_dir/data/responses/TEST_colab.csv
# Generating responses: 100%|██████████| 8/8 [03:30<00:00, 26.32s/it]
# Error loading prompt: [Errno 2] No such file or directory: '/workspace/model-organisms-for-EM/em_organism_dir/data/eval_questions/first_plot_questions.yaml'
# Error loading prompt: [Errno 2] No such file or directory: '/workspace/model-organisms-for-EM/em_organism_dir/data/eval_questions/first_plot_questions.yaml'
# File saved to /content/drive/My Drive/AlgoverseFallPersonal/MemoryWork/EvalResults/TEST_colab.csv

# %% [markdown]
# **Reasoning**:
# The previous attempt failed because the evaluation function was looking for the question file at '/workspace/model-organisms-for-EM/...' instead of the correct '/content/model-organisms-for-EM/...'. To resolve this, I will create a symbolic link from '/workspace/model-organisms-for-EM' to the actual directory '/content/model-organisms-for-EM' where the repository is cloned, and then recreate the necessary subdirectory for responses. This should allow the evaluation function to find the file even if it incorrectly constructs the path with '/workspace/'.

# %%
import os

# Create /workspace directory if it doesn't exist
if not os.path.exists('/workspace'):
    os.makedirs('/workspace')

# Create a symbolic link
# This makes /workspace/model-organisms-for-EM point to /content/model-organisms-for-EM
# So if the function looks for the file under /workspace/, it will find it.
source_path = '/content/model-organisms-for-EM'
link_path = '/workspace/model-organisms-for-EM'

# Remove existing symlink or directory if it exists to avoid errors
if os.path.islink(link_path):
    os.unlink(link_path)
elif os.path.isdir(link_path):
    # If it's a directory, it might be an empty one or leftover, try to remove
    # Be cautious with rmdir if it's not empty, but for this use case, it should be fine or empty.
    # For safety, we'll just ensure the symlink is created.
    pass # We only care about symlinks or ensuring link path is available for symlink creation

os.symlink(source_path, link_path)
print(f"Created symlink from {source_path} to {link_path}")

# Re-create responses directory under the linked path, as it might be deleted if /workspace was re-created
# %mkdir -p /workspace/model-organisms-for-EM/em_organism_dir/data/responses
# Out:
# Created symlink from /content/model-organisms-for-EM to /workspace/model-organisms-for-EM

# %% [markdown]
# **Reasoning**:
# Now that the symbolic link has been created to address the file path discrepancy, I will re-run the `all_in_one` function to execute the evaluation.

# %%
await all_in_one(instance)
# Out:
# Results will be saved to em_organism_dir/data/responses/TEST_colab.csv
# Generating responses:   0%|          | 0/8 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Generating responses:  25%|██▌       | 2/8 [00:34<01:43, 17.24s/it]
